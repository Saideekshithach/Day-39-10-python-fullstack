# %%
#pip install pandas

# %%
import pandas as pd

# %%
a=[10,20,30,40,50]
pd.Series(a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
b=[3.4,6.7,7.8]
pd.Series(b)
# Out:
# 0    3.4
# 1    6.7
# 2    7.8
# dtype: float64

# %%
c=["python","java"]
pd.Series(c)
# Out:
# 0    python
# 1      java
# dtype: object

# %%
d=[4+7j,3+8j]
pd.Series(d)
# Out:
# 0    4.0+7.0j
# 1    3.0+8.0j
# dtype: complex128

# %%
pd.Series(a,index=["i","ii","iii","iv","v"])
# Out:
# i      10
# ii     20
# iii    30
# iv     40
# v      50
# dtype: int64

# %%
data=pd.DataFrame({"name":["rajendra","rajesh","rajeev"],"marks":[60,70,80]})
data
# Out:
#        name  marks
# 0  rajendra     60
# 1    rajesh     70
# 2    rajeev     80

# %%
data1=pd.DataFrame({"names":["pooja","vara"],"mailid":["p@codegnan.com","v@gmail.com"],"salary":[6848936434,648364363]})
data1
# Out:
#    names          mailid      salary
# 0  pooja  p@codegnan.com  6848936434
# 1   vara     v@gmail.com   648364363

# %%
d=pd.read_csv("food.csv")
d
# Out:
#                  Food name      Restaurant
# 0              Veg Biryani  Little village
# 1        Paneer fried rice              F2
# 2             palak paneer          Ismail
# 3         Mushroom biryani    Rusted Spoon
# 4             French fries       Ice Magic
# 5                Ice cream      creamstone
# 6                    pizza         Dominos
# 7                 Panipuri         Gundala
# 8  Pressure cooker biryani       Our place
# 9                 sandwich          zomato

# %%
d.columns
# Out:
# Index(['Food name', 'Restaurant'], dtype='object')

# %%
d.shape
# Out:
# (10, 2)

# %%
d2=pd.read_csv("spotify.csv")
d2
# Out:
#                      track_id                                  track_name  \
# 0      2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1      4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2      59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3      5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4      1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
# ...                       ...                                         ...
# 62312  3eHDwMQYPEziy2DWRBNoLv                        Sani - G.O.A.T Remix
# 62313  5hHtCqkNv5eo99OrEFFcgS                            Life of Bachelor
# 62314  08foF9YHgKmIgOy3xMWRZy                                     Yo Baby
# 62315  2wLFbVlQGKJSd9lwzwL47F                           Fast Fast Vadiley
# 62316  5OYxwYeFfumMTAoAdVeet3             Moonu Moonu Moonu (From "3:33")
#
#                                              artist_name  year  popularity  \
# ...

# %%
d2.shape
# Out:
# (62317, 22)
